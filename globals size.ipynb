# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
N = 1000
xs = np.random.uniform(0, 10.0, N)
ys = xs * 1.22 + np.random.normal(0, 3.0, N)

# %%
xs
# Out:
# array([  5.47070547e+00,   4.29780294e+00,   6.09912355e+00,
#          4.80327375e+00,   7.80944763e-01,   3.38721248e+00,
#          6.12369706e+00,   8.69135174e+00,   6.34665982e+00,
#          3.81281310e+00,   7.11035632e+00,   4.39834653e+00,
#          4.23649299e+00,   1.80134637e+00,   5.70081642e+00,
#          3.51162974e+00,   5.29189775e+00,   9.46630432e+00,
#          4.70612602e+00,   3.76064769e+00,   6.15432352e+00,
#          2.94014093e+00,   7.11622971e+00,   5.43157893e+00,
#          2.38932759e+00,   2.70824601e+00,   6.84507783e+00,
#          2.87705252e+00,   6.13592794e+00,   8.01533036e+00,
#          6.98850817e+00,   8.12265199e+00,   2.56972008e+00,
#          2.31505278e-01,   3.76609488e+00,   8.79671112e+00,
#          5.45465036e+00,   4.43675451e-01,   4.75961862e+00,
#          7.38509708e+00,   1.92200562e+00,   5.45513889e+00,
#          4.69003234e-01,   6.86839728e+00,   5.43109601e-01,
# ...

# %%
import sys

# %%
sys.getsizeof(globals())
# Out:
# 1632
